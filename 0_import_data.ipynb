# %%
# https://www.kaggle.com/competitions/ashrae-energy-prediction/overview

# %% [markdown]
# # Load Packages

# %%
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# # Download Data

# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kaggle

# %%
# !kaggle competitions download -c ashrae-energy-prediction #file downloaded = zip file.  Go unzip it.
# Out:
# ...
#   0%|          | 0.00/379M [00:00<?, ?B/s]
#   0%|          | 1.00M/379M [00:01<10:23, 635kB/s]
#   1%|          | 2.00M/379M [00:02<08:29, 775kB/s]
#   1%|          | 3.00M/379M [00:03<07:44, 848kB/s]
#   1%|1         | 4.00M/379M [00:04<06:11, 1.06MB/s]
#   1%|1         | 5.00M/379M [00:04<04:44, 1.38MB/s]
#   2%|1         | 6.00M/379M [00:05<03:43, 1.75MB/s]
#   2%|1         | 7.00M/379M [00:05<03:03, 2.12MB/s]
#   2%|2         | 8.00M/379M [00:05<02:38, 2.45MB/s]
#   2%|2         | 9.00M/379M [00:05<02:21, 2.74MB/s]
#   3%|2         | 10.0M/379M [00:06<02:08, 3.01MB/s]
#   3%|2         | 11.0M/379M [00:06<02:00, 3.20MB/s]
#   3%|3         | 12.0M/379M [00:06<01:55, 3.33MB/s]
#   3%|3         | 13.0M/379M [00:07<01:50, 3.48MB/s]
#   4%|3         | 14.0M/379M [00:07<01:47, 3.56MB/s]
#   4%|3         | 15.0M/379M [00:07<01:45, 3.62MB/s]
#   4%|4         | 16.0M/379M [00:07<01:39, 3.84MB/s]
#   4%|4         | 17.0M/379M [00:08<01:37, 3.88MB/s]
# ...

# %% [markdown]
# # Load all of the data
#
# important notes!
# 1) site 0 is in kbtu whereas all other sites are kwh.
# kbtu\*0.2931 = kwh.
# kwh\*3.4118 = kbtu

# %%
# Find our directory
directory = !dir
for d in directory:
    if "Directory" in d:
        print(d[14:])
        path = d[14:]
path = path.replace('\\', '/')
print(path)
# Out:
# C:\Users\jleechc2\OneDrive - Johnson Controls\custom_projects\great_energy_predictor
# C:/Users/jleechc2/OneDrive - Johnson Controls/custom_projects/great_energy_predictor

# %%
# Look at our directory of files
for f in glob.glob(f"{path}/ashrae-energy-prediction/*"):
    filename=f.split("\\")[1][:-4]
    print(f"'{f}',")
    print(f"'{filename}',")
# Out:
# 'C:/Users/jleechc2/OneDrive - Johnson Controls/custom_projects/great_energy_predictor/ashrae-energy-prediction\building_metadata.csv',
# 'building_metadata',
# 'C:/Users/jleechc2/OneDrive - Johnson Controls/custom_projects/great_energy_predictor/ashrae-energy-prediction\sample_submission.csv',
# 'sample_submission',
# 'C:/Users/jleechc2/OneDrive - Johnson Controls/custom_projects/great_energy_predictor/ashrae-energy-prediction\test.csv',
# 'test',
# 'C:/Users/jleechc2/OneDrive - Johnson Controls/custom_projects/great_energy_predictor/ashrae-energy-prediction\train.csv',
# 'train',
# 'C:/Users/jleechc2/OneDrive - Johnson Controls/custom_projects/great_energy_predictor/ashrae-energy-prediction\weather_test.csv',
# 'weather_test',
# 'C:/Users/jleechc2/OneDrive - Johnson Controls/custom_projects/great_energy_predictor/ashrae-energy-prediction\weather_train.csv',
# 'weather_train',

# %%
# read each table to dataframe
all_data = {}

for f in glob.glob(f"{path}/ashrae-energy-prediction/*"):
    filename=f.split("\\")[1][:-4]
    file_path = f"{path}/ashrae-energy-prediction/{filename}.csv"
    file_size = os.path.getsize(file_path)

    print(f"File/Size: {filename} / {file_size/1024/1024:.1f} MB")    
    
    df = pd.read_csv(f"{file_path}")
    all_data[filename] = df

all_data.keys()
# Out:
# File/Size: building_metadata / 0.0 MB
# File/Size: sample_submission / 426.8 MB
# File/Size: test / 1394.7 MB
# File/Size: train / 647.2 MB
# File/Size: weather_test / 14.1 MB
# File/Size: weather_train / 7.1 MB
# dict_keys(['building_metadata', 'sample_submission', 'test', 'train', 'weather_test', 'weather_train'])

# %%
display(all_data['building_metadata'].head(1))
display(all_data['train'].head(1))
display(all_data['test'].head(1))
display(all_data['weather_train'].head(1))
display(all_data['weather_test'].head(1))
display(all_data['sample_submission'].head(1))
# Out:
#    site_id  building_id primary_use  square_feet  year_built  floor_count
# 0        0            0   Education         7432        2008          NaN
#    building_id  meter            timestamp  meter_reading
# 0            0      0  2016-01-01 00:00:00              0
#    row_id  building_id  meter            timestamp
# 0       0            0      0  2017-01-01 00:00:00
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 0        0  2016-01-01 00:00:00               25               6
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0               20                NaN                1020               0
#
#    wind_speed
# 0           0
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 0        0  2017-01-01 00:00:00               18               4
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0               12                NaN                1021             100
# ...
